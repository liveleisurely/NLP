# %% [markdown]
# # English Wordcloud

# %%
from wordcloud import WordCloud
from nltk.tag import pos_tag
from collections import Counter
import re
#nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to /root/nltk_data...
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to /root/nltk_data...
# [nltk_data]    | Downloading package crubadan to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/extended_omw.zip.
# [nltk_data]    | Downloading package floresta to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to /root/nltk_data...
# [nltk_data]    | Downloading package kimmo to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to /root/nltk_data...
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to /root/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to /root/nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to /root/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to /root/nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/omw.zip.
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/omw-1.4.zip.
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package paradigms to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pe08 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package pil to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package porter_test to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to /root/nltk_data...
# [nltk_data]    | Downloading package pros_cons to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package ptb to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package qc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    | Downloading package rslp to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package rte to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to /root/nltk_data...
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package verbnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to /root/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /root/nltk_data...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-118-4420e2a20063> in <module>()
#       3 from collections import Counter
#       4 import re
# ----> 5 nltk.download('all')
#
# /usr/local/lib/python3.7/dist-packages/nltk/downloader.py in download(self, info_or_id, download_dir, quiet, force, prefix, halt_on_error, raise_on_error)
#     668                                     subsequent_indent=prefix+prefix2+' '*4))
#     669
# --> 670             for msg in self.incr_download(info_or_id, download_dir, force):
#     671                 # Error messages
#     672                 if isinstance(msg, ErrorMessage):
#
# /usr/local/lib/python3.7/dist-packages/nltk/downloader.py in incr_download(self, info_or_id, download_dir, force)
#     547         if isinstance(info, Collection):
#     548             yield StartCollectionMessage(info)
# --> 549             for msg in self.incr_download(info.children, download_dir, force):
#     550                 yield msg
#     551             yield FinishCollectionMessage(info)
#
# /usr/local/lib/python3.7/dist-packages/nltk/downloader.py in incr_download(self, info_or_id, download_dir, force)
#     533         # If they gave us a list of ids, then download each one.
#     534         if isinstance(info_or_id, (list,tuple)):
# --> 535             for msg in self._download_list(info_or_id, download_dir, force):
#     536                 yield msg
#     537             return
#
# /usr/local/lib/python3.7/dist-packages/nltk/downloader.py in _download_list(self, items, download_dir, force)
#     576             else:
#     577                 delta = len(item.packages)/num_packages
# --> 578             for msg in self.incr_download(item, download_dir, force):
#     579                 if isinstance(msg, ProgressMessage):
#     580                     yield ProgressMessage(progress + msg.progress*delta)
#
# /usr/local/lib/python3.7/dist-packages/nltk/downloader.py in incr_download(self, info_or_id, download_dir, force)
#     553         # Handle Packages (delegate to a helper function).
#     554         else:
# --> 555             for msg in self._download_package(info, download_dir, force):
#     556                 yield msg
#     557
#
# /usr/local/lib/python3.7/dist-packages/nltk/downloader.py in _download_package(self, info, download_dir, force)
#     622                 num_blocks = max(1, info.size/(1024*16))
#     623                 for block in itertools.count():
# --> 624                     s = infile.read(1024*16) # 16k blocks.
#     625                     outfile.write(s)
#     626                     if not s: break
#
# /usr/lib/python3.7/http/client.py in read(self, amt)
#     463             # Amount is given, implement using readinto
#     464             b = bytearray(amt)
# --> 465             n = self.readinto(b)
#     466             return memoryview(b)[:n].tobytes()
#     467         else:
#
# /usr/lib/python3.7/http/client.py in readinto(self, b)
#     507         # connection, and the user is reading more bytes than will be provided
#     508         # (for example, reading in 1k chunks)
# --> 509         n = self.fp.readinto(b)
#     510         if not n and b:
#     511             # Ideally, we would raise IncompleteRead if the content-length
#
# /usr/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /usr/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# 1. 텍스트 불러오기
with open('/content/drive/MyDrive/dataset/text/crypto_word.txt','r') as f:
    text = f.readlines()

# %%
new = []
for i in text:
    new.append(i.replace('\n',''))
new
# Out:
# ['Why Crypto Stocks Are Performing Worse Than Cryptocurrencies',
#  'Can Elon Musk Buy All of Twitter? How Tesla’s CEO Made His Fortune',
#  'How the IRS Is Cracking Down on Crypto Tax Cheats',
#  'Ukraine, Russia Meet in Turkey for Cease-Fire Talks',
#  'Opinion: El Salvador Bets on Bitcoin Mania',
#  'Wall Street Has Been Betting Billions on Crypto. Here’s Why.',
#  'El Salvador Asks: Can Bitcoin Be a Nation’s Currency?',
#  'U.S. Stocks Jump as War in Ukraine Continues Fueling Big Market Moves',
#  'Crypto in Wartime: Bitcoin’s Role in the Russia-Ukraine Crisis',
#  'What Comes Next in El Salvador’s Bitcoin Experiment?',
#  'Why Some See Web 3.0 as the Future of the Internet',
#  'Volatile Trading Day Leaves U.S. Stocks Mostly Lower',
#  'Turkish Investors Pivot to Cryptocurrencies as Inflation Soars, Lira Slides',
#  'Opinion: Cryptocurrencies, Criminality and the State',
#  'Federal Reserve Signals Rate Hike in March; U.S. Stocks Turn Lower',
#  "Wall Street's Roller-Coaster Ride: What Comes Next?",
#  'Opinion: Cryptocurrency Doesn’t Amount to Much',
#  'Bitcoin Price Falls in Tandem With Tech Selloff',
#  'Opinion: Congress Treats Bitcoin Like Stacks of Cash',
#  'Interest-Rate Worries Spark Choppy Market Trading Session',
#  'Stocks Fall in Late Trading',
#  'Why Crypto Lending’s Risks May Spark a Serious Regulator Crackdown',
#  'Opinion: America’s Future Depends on the Blockchain',
#  'How to Give Crypto, NFTs and Digital Money This Holiday Season',
#  "Giving Bitcoin as a Holiday Gift? Here's What to Know.",
#  'Nasdaq Leads U.S. Stock Markets Lower',
#  'Opinion: No Deposit Insurance for Crypto',
#  'Opinion: The Fed Battles Wyoming on Cryptocurrency',
#  "Bitcoin's Mysterious Creator Could Be Uncovered by Florida Jury",
#  'Opinion: Crypto Is Shedding Its Tether',
#  'Are Corporate Boards Heeding Pressure to Diversify?',
#  'Bitcoin ETFs: What to Know If You Plan to Invest',
#  'U.S. Stocks Finish Mixed After Weak China Growth Data',
#  'Opinion: Coinbase CEO: We Need a New Approach to Regulating Crypto',
#  'Opinion: How to Get Cryptocurrency Regulation Right',
#  'Cardano’s Ada Wants to Solve Some of Crypto’s Biggest Challenges',
#  'Energy Stocks Rally as Investors Bet on Economic Reopening',
#  'Dow, S&P Edge Higher After Evergrande Payment Deadline Passes',
#  'How to Invest Without Emotions Clouding Your Judgement',
#  'Antony Blinken to Face Lawmakers Over Afghanistan Withdrawal',
#  'Opinion: El Salvador Runs a Bitcoin Scam',
#  "What El Salvador's Bitcoin Experiment Looks Like",
#  'Opinion: Dollars for Duds in Latin America',
#  'The Benefits of Diversifying Your Portfolio',
#  'U.S. Stocks Jump After FDA Approves Covid-19 Vaccine',
#  'China’s Tough Stance on Crypto Mining Is a Boon for Miners Elsewhere',
#  'Dow, S&P Hit Fresh Records',
#  "Crypto Scams Are on the Rise. Here's What to Watch Out For.",
#  'Opinion: Bitcoin Law in El Salvador Denies Its People a Choice',
#  'Opinion: Bitcoin Experiment in El Salvador Does Not Threaten Freedom',
#  'Opinion: Roadblocks Ahead for El Salvador’s Crypto Paradise',
#  'John McAfee, Software Pioneer, Found Dead',
#  'Opinion: El Salvador’s Big Bitcoin Mistake',
#  'Opinion: Untraceable Bitcoin Is a Myth',
#  'Opinion: A Global First: Bitcoin as National Currency',
#  "Tech Stocks' Gains Push Nasdaq to Record High",
#  'Could Cryptocurrency Be Coming to Retirement Plans?',
#  "Trump's TikTok, WeChat Orders Revoked by Biden",
#  'Elon Musk’s Power Over Crypto, Explained',
#  'How Scammers Are Taking Advantage of the Bitcoin Boom',
#  'Investigators Seize Bitcoin Paid in Colonial Pipeline Ransomware Attack',
#  'Opinion: Crypto Needs Regulation, but It Doesn’t Need New Rules',
#  'Inflation in Wealthy Nations Hits 12-Year High',
#  'Investor Comfort With Pace of Recovery Pushes Markets Higher',
#  'Stocks and Bitcoin Move Higher to Begin the Week',
#  'U.S. Stocks End Bumpy Week With Mixed Session',
#  'Existing-Home Sales Fall for Third Straight Month',
#  'More Than 20 States Plan to End Extra Federal Jobless Benefits',
#  'Bitcoin Volatility Signals a Long Road to Adoption',
#  'Stocks, Bitcoin Drop as Investors Retreat From Riskier Assets',
#  'U.S. Stocks Finish Lower to Start the Week',
#  'Crypto Venture Firm Framework Draws Institutional Support',
#  'Nasdaq Drops 1.9% as Tech Stocks Fall',
#  'Does Bitcoin Have a Place in an Investment Portfolio?',
#  'What Coinbase’s Public Debut Means for Bitcoin and Crypto',
#  'Why China Is Jumping Into Digital Currency',
#  "In Bitcoin's Shadow, Stablecoins Thrive but Face Challenges",
#  'The Oakland A’s Offer a Suite Bitcoin Deal',
#  'Tax Week: Investments and Your Tax Return',
#  "Bitcoin Hits $50,000: What's Fueling the Rally?",
#  'CFOs Hesitate to Invest in, Handle Bitcoin Due to Volatility',
#  'Opinion: Can You Get Rich With Bitcoin? Sure, but Slowly',
#  'Bitcoin Jumps More Than 10% on Tesla Investment',
#  'Tesla Invests $1.5 Billion in Bitcoin',
#  'Dogecoin: Elon Musk, Snoop Dogg Tweets Fuel Crypto Price Rally',
#  'Opinion: Behind the Bitcoin Bubble',
#  'Fake Covid-19 Vaccines: What to Know About Counterfeit Shots Sold Online',
#  'Why Investors Are Piling Into Bitcoin Despite the Risks',
#  'Why Bitcoin Prices Are Soaring Again',
#  'Dow Caps Best Month Since 1987',
#  'Bitcoin Is Riding High Again as Investors Embrace Risk',
#  '‘Billions’ Recap, Season Five Premiere: Enlightenment and ‘Deca’-dence',
#  'Opinion: Venezuela Puts the Crypt in Cryptocurrency',
#  'Bitcoin Rebounded in 2019, but Challenges Loom',
#  'Bitcoin: What Could Trigger Another Rally?',
#  'Hackers Swipe More Than $40 Million of Bitcoin From Cryptocurrency Exchange',
#  'When Warren Buffett Takes the Stage, Try Your Hand at Berkshire Bingo',
#  'Bitcoin Venture Backed by NYSE Owner Faces Fresh Delay',
#  'Big Bitcoin Exchange Ends Bid to Lure High-Speed Traders',
#  'Private-Jet Cryptocurrency Gets Pass From SEC',
#  'Bitcoin Rises 16%, Touching $5,000 in Asia',
#  'Cryptocurrency: Coinbase Offers Interest to Park Cash',
#  'Bitcoin in the Wilderness',
#  'Cryptocurrency Miner Bitmain’s IPO Application Lapses',
#  'Real Time Economics: The Fed’s On Hold, U.S.-China Talks Are a Go',
#  'Bitcoin: The Crypto Winter of Our Discontent',
#  'Former Mt. Gox Bitcoin Bigwig Unlikely to Do More Jail Time',
#  'Customers Hunt for Bankrupt Crypto Exchange’s Missing Millions',
#  'A Crypto-Mystery: Is $136 Million Stuck or Missing?',
#  'Two Groups Likely Stole $1 Billion in Cryptocurrency Hacks',
#  'Are ICO Tokens Securities? Startup Wants a Judge to Decide',
#  'Who Is the CryptoMom, and Why Do Crypto Startups Like Her?',
#  'Outsmart the Scammers: How You Can Avoid Fraud',
#  'Meet the Watchdog Called CryptoMom',
#  'In a World Without Hard Cash, What’s Left To Steal?',
#  'Crypto Investors Look for Rebound After Sharp Decline',
#  'Once a Rebel, Bitcoin Is Conforming to Mainstream Markets',
#  'A Flood of Questionable Cryptocurrency Offerings',
#  'Make The Most of Your Failed Bitcoin Gamble: Sell Now',
#  'Cryptocurrency Contracts Will Pay in Bitcoin',
#  'Blockchain Beyond the Hype',
#  'Blythe Masters, a Former Wall Street Star, Resigns From Blockchain Startup',
#  'The Morning Download: Beyond Bitcoin, the Future of Blockchains in the Enterprise',
#  'Bitcoin: Bubble, Or No Bubble?',
#  'Bitcoin Wasn’t a Bubble Until It Was',
#  'Layoffs Become the Latest Thing in Cryptocurrency',
#  'Thematic ETFs Are the Rage—Until They Fail',
#  'Iranians Indicted in Atlanta for Cyberattack',
#  'In the Elevator With Coinbase CEO Brian Armstrong',
#  'Pay Taxes With Bitcoin? Ohio Says Sure',
#  'Real Time Economics: Brexit or Bust, the Price of Climate Change and Bitcoin’s Bad Week',
#  'Bitcoin Volatility Drops Despite Turmoil Elsewhere',
#  'Digital Currency Volatility Has Crypto Startups Playing Wealth Managers',
#  'The Bitcoin Gamble',
#  'The Man Who Bet It All on Bitcoin, and Still Believes',
#  'Bitcoin Turns 10: Still Not All Grown Up',
#  'Can Bitcoin Become a Dominant Currency?',
#  'Fidelity Says It Will Trade Bitcoin for Hedge Funds',
#  'Plan to Fix Journalism With Cryptocurrency Draws Skepticism',
#  'Cryptocurrency Scams Bring Ramped Up Enforcement',
#  'Cryptocurrencies, Trading Scams Draw Enforcement Rise',
#  'WSJCoin: To Understand Cryptocurrencies, We Created One',
#  'WSJCoin: To Understand Cryptocurrencies, We Created One',
#  'Bitcoin’s 10th Birthday Won’t Be a Happy One',
#  'Cryptocurrencies and Blockchains: How Are They Doing After 10 Years?',
#  'Crypto Meets Wall Street as Bitcoin Mining Giant Files for IPO',
#  'Bitcoin ETFs Keep Trying, Despite Regulators’ Rejections',
#  'Crypto Pioneer David Chaum Says He’s Built a Better Bitcoin',
#  'Cryptocurrency Exchanges Vulnerable to Manipulation, Report Finds',
#  'It Was Meant to Be the Better Bitcoin. It’s Down Nearly 90%',
#  'Nvidia Clears Its Crypto Cloud',
#  'Real Time Economics: Trade, Tariffs, Currencies and the Weaponization of International Finance',
#  'Cryptocurrency Market Plumbs New Depths in 2018',
#  'The Mystery Behind Tether, the Crypto World’s Digital Dollar',
#  'The Man Who Solved Bitcoin’s Most Notorious Heist',
#  'Bitcoin Detectives: Cracking the \u200bBlockchain',
#  'Some Traders Are Talking Up Cryptocurrencies, Then Dumping Them, Costing Others Millions',
#  'The Emergence of a Blockchain-Based Token Economy',
#  'NYSE’s Owner to Launch Bitcoin Firm, Futures Contracts',
#  'Corruption Currents: Ex-South African Leader’s Corruption Trial Postponed',
#  'Is Bitcoin Back? Cryptocurrency Crosses $8,000 for First Time in Two Months',
#  'Bitcoin Fever Persists With Fresh ETF Proposal',
#  'Bitcoin Roars Back to Life',
#  'How Bitcoin Fueled Russian Hacks',
#  'The Morning Download: Nasdaq Blends Artificial and Human Intelligence',
#  'New York Stock Exchange Executive to Join Winklevoss Bitcoin Firm',
#  'A Fifth of All Bitcoin Is Missing. These Crypto Hunters Can Help',
#  'What Crypto Downturn? ICO Fundraising Surges in 2018',
#  'You Can Like Bitcoin Again',
#  'Court Blocks Payday for Chief of Bankrupt Mt. Gox Bitcoin Exchange',
#  'Jack Ma Slams Bitcoin Speculation While Launching Remittance Service Built on Blockchain',
#  'Bitcoin Drop Sparks Broad Cryptocurrency Selloff',
#  'Cryptocurrency Exchange Bithumb Loses More Than $30 Million in Hack',
#  'Is Bitcoin the Future, or an Echo of a Failed Past?',
#  'Bitcoin Pushes Ancient Gold Market to Try Digital',
#  'Crypto Market Rallies on SEC’s Official’s Ether Stance',
#  'Ether Shouldn’t Be Subject to SEC Regulation, Official Says',
#  'Inside the Chaotic Launch of a $4 Billion Crypto Project',
#  'New Bitcoin ETF Would Set Buyers Back $200,000',
#  'Coinbase Wants to Pounce on Another Cryptocurrency Paradise: Japan',
#  'Can the Biggest U.S. Bitcoin Exchange Woo Wall Street?',
#  'The Eureka Moment That Made Bitcoin Possible',
#  'Battle for Developers Escalates at Blockchain Startups',
#  'Small Banks’ New Money Maker: Bitcoin',
#  'Consensus Is, Not a Good Week for Bitcoin',
#  'Buyer Beware: Hundreds of New Cryptocurrencies Show Hallmarks of Fraud',
#  'Bitcoiners Take New York, but Wall Street Resists The Lure',
#  'Big Bitcoin Exchange Welcomes High-Speed Traders',
#  'Are Ether Futures Next?',
#  'Steve Eisman of ‘The Big Short’ Bashes Cryptocurrency: ‘I Don’t See the Purpose of It’',
#  'Corruption Currents: AT&T CEO Admits Cohen Payment a ‘Big Mistake’',
#  'Bitcoin Prices Slide as South Korea’s Largest Crypto Exchange Gets Raided',
#  'Jetpacks and Tech-Enabled Cities: How We’ll Live in the Future',
#  'Debut of Bitcoin Futures Triggered Crash in Price',
#  'Fed Paper Ties Launch of Futures Contracts to Bitcoin’s Fall',
#  'Blockchain ETF Asks for Patience',
#  'Square’s Loss Widens as Spending Picks Up',
#  'Telegram Messaging App Scraps Plans for Public Coin Offering',
#  'Regulators Weighing New Push on Cybercurrencies',
#  'Peter Thiel-Backed Venture to Help Big Investors Bet on Bitcoin',
#  'The Crypto Crime Wave Is Here',
#  'Winklevosses’ Bitcoin Exchange to Use Nasdaq Surveillance Software',
#  'Ghosn: Merger Isn’t the Only Option for Renault, Nissan',
#  'The Morning Risk Report: Commerce Dept. Sends Strong Message in ZTE Ban',
#  'New York Pushes Crypto Exchanges for More Transparency',
#  'Cryptocurrency Exchange Kraken Pulls Out of Japan',
#  'Crypto Hedge Fund Says Worst Is Over for Bitcoin',
#  'Bitcoin’s Hype Fizzles: ‘We’re in the Boring Phase’',
#  'Nasdaq To Delist Long Blockchain as Pivot From Tea Fizzles',
#  'Townhouse Listed for $30 Million—or $45 Million in Bitcoin',
#  'Transcript: Audience Q&A With San Francisco Fed’s John Williams',
#  'Coinbase in Talks to Become Regulated Brokerage',
#  'Regulators Are Cracking Down on Cryptocurrencies. India’s Next.',
#  'March Went Out Like a Lamb for Initial Coin Offerings',
#  'Swiss Central Banker Warns of Cryptocurrency Risks',
#  'Saudis Find Source of Free Energy',
#  'Coincheck, Roiled by Hack, Might Have Found Its White Knight',
#  'Bitcoin’s First-Quarter Play: Falling Back to Earth',
#  'South Korean Insurer Denies Hacked Cryptocurrency Exchange’s Claim',
#  'Bitcoin’s Rise and Fall Looks Just Like Dot-Com’s Boom and Bust…Kind of',
#  'Overstock Misses out on Bitcoin Magic',
#  'Bank of England Says No Current Risk to U.K. From Cryptocurrencies',
#  'Do You Own Bitcoin? The IRS Is Coming for You',
#  'South Korea Confiscated Computers, Records in Cryptocurrency Raids',
#  'Bitcoin Prices Slide Further',
#  'Chernova’s Take: When Crypto Investors Offer More Than Cash',
#  'When Will Stocks Tumble Again? Investors Look to Bitcoin for Answers',
#  'Why Blockchain Will Survive, Even If Bitcoin Doesn’t',
#  'Mt. Gox Trustee Sells $400 Million of Bitcoin and Bitcoin Cash',
#  'Bank of France Urges Tighter Digital Currency Regulation',
#  '‘Anything Goes’ for Issuing New ETFs? Not Anymore',
#  'Crypto Investing Comes With a Big Risk: The Exchanges',
#  'Cryptocurrencies Are Failing as Money, Says BOE’s Carney',
#  'Real Time Economics: Central Bankers Warn on Bitcoin | The ECB Worries About FX | Businesses Rethink Tax Strategy',
#  'Fed’s Dudley Warns on Cryptocurrencies',
#  'Bitcoin Is Falling Fast, Losing More Than Half Its Value in Six Weeks',
#  'India Plans Crackdown on Cryptocurrency Misuse',
#  'Bitcoin Has Its Worst Month in Three Years',
#  'Investors Can’t Split Difference With Bitcoin',
#  'Investor Who Rode Pivot From Biotech to Bitcoin Sells Big Stake',
#  'Want to Keep Up With Bitcoin Enthusiasts? Learn the Lingo',
#  'Coincheck to Pay Back Customers',
#  'Lured by Hot Bets, Individual Investors Dive In',
#  'Hedge Funds Go Bullish on Bitcoin Futures',
#  'Dinner in Davos: Glenn Hutchins in Conversation With Gerard Baker',
#  'Opinion: Regulators Are Looking at Cryptocurrency',
#  'Investors Snapping Up New Blockchain ETFs',
#  'Got ID? Korea Tightens Noose on Anonymous Cryptocurrency Trading',
#  'After Bitcoin Futures, Watch Out for Crypto Repos',
#  'The Morning Download: China, Unencumbered by Rules, Races Ahead in Gene Editing',
#  'South Korea’s Cryptocurrency Crackdown Isn’t Stopping This Bitcoin Exchange’s Launch',
#  'What Your CEO Is Reading: Overworked vs. Overperked; Back to Blockchain; Rate the Boss',
#  'Let Me Tell You Some More About Bitcoin—Hello? Hello?',
#  'Bitcoinfreude Can Be Mean',
#  'Survey Roundup: Climate Change Cracks Top Risks List for First Time',
#  'Bitcoin Finds a Home in Cash-Loving Germany',
#  'Beware: Even Joke Cryptocurrencies Are Going Through the Roof',
#  'The Morning Download: Millennial IT Buyers Do Things Differently',
#  'Bitcoin Extends Rout, Dipping Below $10,000',
#  'Just Another Day for Bitcoin—a 25% Plunge',
#  'What’s in a Name? For Two Blockchain ETFs, Not the Word ‘Blockchain’',
#  'Midday Brief for Tuesday, January 16th',
#  'The Morning Download: Alibaba, Microsoft AI Bests Human Reading Comprehension',
#  'Uproar as South Korea Plans Cryptocurrency Crackdown',
#  'JPMorgan’s Profit Hurt by Tax Law',
#  'MoneyGram Signs Deal With Currency Startup Ripple',
#  'Bitcoin Plunges as South Korea Crafts Crypto Crackdown',
#  'The Morning Download: Nissan Researcher Developing Brain-to-Vehicle Interface',
#  'China Quietly Orders Closing of Bitcoin Mining Operations',
#  'Kodak Enters the Digital Currency World',
#  'Kodak Catches Crypto Fever',
#  'Bitcoin Powers Big Returns for a Pair of ETFs',
#  'Warren Buffett Is No Fan of Cryptocurrencies',
#  'Boards Seek Bigger Role in Thwarting Hackers',
#  'Opinion: Tales From the Cryptocurrency',
#  'Bitcoin Cash, Litecoin, Ether, Oh My! What’s With All the Bitcoin Clones?',
#  'Bitcoin Plunges 25% in 24 Hours in a Cryptocurrency Market Rout',
#  'Why Michael Novogratz Halted His Bitcoin Hedge Fund',
#  'Corruption Currents: Two Convicted at FIFA Trial',
#  'Bitcoin Flips Between Bull and Bear Markets Almost Once a Month',
#  'The Morning Download: CIOs Say Virtual Reality, Quantum Computing Are Ready to Emerge',
#  'Cryptocurrency Founder Tries a New Play: Sell It All',
#  'How to Answer All Your Family’s Tech Questions',
#  'Iced Tea Company Pivots to Blockchain; Shares Surge',
#  'Bitcoin Price Plunges, Recovers as Bitcoin Offshoot Blasts Off',
#  'The Morning Download: CIOs See More Opportunities for Automation',
#  'Bitcoin Too Expensive? There Are Others to Invest In',
#  'Bitcoin Swings as Alternative Is Added to Exchange',
#  'Good News! You Are a Bitcoin Millionaire. Bad News! You Forgot Your Password',
#  'Which Digital Currency Will Be the Next Bitcoin?',
#  'Stocks Soar; Activist Investors Wield Power',
#  'Holiday Shopping With Bitcoin? Good Luck With That!',
#  'Bitcoin Overtakes Tech as ‘Most Crowded Trade,’ Fund Managers Say',
#  'The Morning Download: Tech Giants May Pay More Tax on Foreign Profits',
#  'Cryptocurrency Exchange Collapses, Files for Bankruptcy After Hack',
#  'Digital Coin Offerings Don’t Mask Normal Money-Laundering Risk',
#  'The Flawed Bull Case for Bitcoin',
#  'Why Bitcoin’s Rally May Be ‘Self-Defeating’',
#  'Investors Shell Out $700 Million for Coins With ‘No Purpose’',
#  'Exchange Giant CME Launches Bitcoin Futures',
#  'Bitcoin Futures Manipulation 101: How ‘Banging the Close’ Works',
#  'You Can Thank Mr. Watanabe for Bitcoin’s Explosive Rally',
#  'Opinion: What Bitcoin Needs Is a Few Good Regulations',
#  'Long Island Woman Charged With Trying to Fund ISIS',
#  'Bank of Canada Head Likens Bitcoin Mania to ‘Gambling’',
#  'Opinion Journal: Bitcoin’s Big Problem: Energy',
#  'Stock Market This Year Is Calmest in Half a Century',
#  "Why We Shouldn't Call This Market Run-Up a 'Trump Rally'",
#  'Who’s Looking to Cash In on the Bitcoin Boom Now? The Taxman',
#  'Special Fed Coverage: Yellen Press Conference',
#  'As Other Markets Stall, Traders Rush Into Bitcoin Boom',
#  'Bitcoin Made This Man (Briefly) One of the Richest People in America',
#  'What You Can Buy With Bitcoin: A $10 Pizza for $76',
#  'Is Bitcoin a Bubble? 96% of Economists Say ‘Yes’',
#  'Greek Court Backs Extraditing Russian Bitcoin Suspect to U.S.',
#  'HFR Launches Cryptocurrency Index as Fund Managers Eye Red-Hot Sector',
#  'The Morning Risk Report: HSBC Case Set Compliance Trends in Banking',
#  'After Bitcoin Futures, an ETF Could Be Next',
#  'The Force Behind Bitcoin’s Meteoric Rise: Millions of Asian Investors',
#  'The Morning Risk Report: U.K. Govt Review Clears Way for Recruiting New SFO Head',
#  'Opinion: Hooray for Bitcoin (but Don’t Buy It)',
#  "NYC Mayor: Explosion Was 'Attempted Terrorist Attack'",
#  'App Maker Halts Initial Coin Offering After SEC Investigation',
#  'Bitcoin Buyers Get Unwanted Message: Wait in Line',
#  'Stop Talking About Bitcoin’s Market Cap',
#  'One Sign Mom and Pop Are Jumping Into Bitcoin',
#  'The Morning Download: Big Companies Give Algorithms Chance to Manage People',
#  'The Morning Risk Report: Insurance Commissioners Roll Out Model Cybersecurity Law',
#  'Where to Put Your Money in the Next Year',
#  'Why Bitcoin? Why Now?',
#  'Bitcoin 101: What It Is, How to Invest',
#  'Bitcoin Futures Promise Wild Ride for Risk-Loving Traders',
#  'France Widens Acceptance of Blockchain',
#  'A Stock Picker’s Guide to Playing Bitcoin',
#  'The Morning Download: Ethereum Blockchain Faces Test as CryptoKitties Go Viral',
#  "Bitcoin Futures: Why Some Big Banks Aren't on Board",
#  'Hackers Steal $70 Million in Bitcoin',
#  'Bitcoin’s Wildest Rise: 40% in 40 Hours',
#  'Union Official’s Grilling of Bitcoin Expert Draws Rebuke from SEC Commissioner',
#  'The Morning Risk Report: Companies Have Little Faith in Cybersecurity Capabilities',
#  'Gold Trading Hasn’t Been This Quiet Since 2005',
#  'Australia Banks on Bitcoin Tech to Keep Tabs on Stocks',
#  'Bitcoin Tops $13,000 Hours After Passing $12,000',
#  'Bitcoin Price Mania: A BTC ATM Experiment',
#  'Civic’s Vinny Lingham Joins Crypto Fund Multicoin',
#  'The Morning Download: Five Key Things About the Tax Overhaul R&D Debate',
#  'The Winkelvii Are Halfway Cool',
#  'Is It Time to Regulate Bitcoin?',
#  'How I Bungled the Timing of My Bitcoin Investment',
#  'SEC Chairman Clayton Says Agency Is Not Done in Addressing Uses of Bitcoin',
#  'First U.S. Bitcoin Futures to Start Trading Next Week',
#  'The Morning Risk Report: U.K. Sanctions Bill Raises Concerns Over Govt Powers',
#  'Will Bitcoin Futures Help Stabilize Volatility?',
#  'Will Fed Catch Digital-Currency Fever?',
#  'Bitcoin Futures Set to Start Trading as Regulator Gives Thumbs Up',
#  'The Morning Download: Waymo Lets Autonomous Vehicle Drive Without Human Backup Behind Wheel',
#  'Tame Bitcoin’s Price Swings? There’s a Plan for That',
#  'Test Your Smarts on…Foreign Currencies',
#  'Bitcoin Hits $7,000 as Wall Street Interest Gets Real',
#  'Gold Bugs Embrace Bitcoin, Upending Retail Sellers',
#  'In Mainstream Move, Bitcoin Poised to Join Oil, Gold in Futures Trading',
#  'Five Things to Know About Bitcoin and the Race to Launch Derivatives',
#  'The Morning Risk Report: U.S. Companies Target Vendors In Third-Party Assessments',
#  'Your Computer May Be Making Bitcoin\u200b for Hackers',
#  'Bitcoin’s Sectarian Battles Heat Up',
#  'How an Analyst Thinks Bitcoin’s Volatility Is Predictable',
#  'Latest Use for Blockchain Technology: Tracing Turkeys',
#  'New Ransomware Outbreak Spreads Through U.S., Russia and Ukraine',
#  'Leaving Bitcoin on the Table',
#  'Former Energy Trader Goes All-In on Bitcoin',
#  'Closing Bell Brief for Friday, October 20th',
#  'Bitcoin Buyers Should Heed Lessons of China’s Bubbles',
#  'Coin Offering Raises $232 Million, Then a Fight Broke Out',
#  'J.P. Morgan’s Dimon May Hate Bitcoin, but He Loves Blockchain',
#  'Should Individuals Invest in Bitcoin?',
#  'Why James Dimon and Larry Fink Aren’t Buying Bitcoin',
#  'Basecoin Token Developers Seeded by Andreessen, Bain and Others',
#  'Bitcoin Surges Above $5,200 on Hopes of Renewed China Trade',
#  'Should Individuals Invest in Bitcoin? Advisers Say No',
#  'Why Bitcoin’s Bubble Matters',
#  'Company Plays the Name Game',
#  'After Bitcoin Crackdown, Cryptocurrencies Go Clandestine in China',
#  'The Morning Download: CIOs Face Challenge of Scaling Digital Business',
#  'Bitcoin Bounces Around Wildly in Record-Setting Quarter',
#  'Bitcoin’s Lot: Win Some, Lose Some',
#  'South Korea Joins Cryptocurrency Crackdown',
#  'Opinion: The Blockchain Is the Internet of Money',
#  'ECB’s Draghi Pours Cold Water on Virtual Currencies',
#  'Bitcoin ‘Fugitives’ Gather in Hong Kong to Skirt China’s Curbs',
#  'Nvidia’s Gains Are Real, Not Virtual',
#  'Chernova’s Take: The Coming Threat to Crypto Crowdfunding',
#  'China Widens Bitcoin Crackdown Beyond Commercial Trading',
#  'Bitcoin Losses Worsen as Chinese Exchange Closes',
#  'Red-Hot Bitcoin, Down for Sixth Straight Day, Looking Suddenly Bearish',
#  'The Morning Download: Apple’s New iPhone Poised to Expand Role of Smartphone in Enterprise Apps',
#  'Bitcoin Monday: From Record High to Down 10% Before You Got Out of Bed',
#  'Bitcoin Drives to a New High, but Is It Headed for a Crash?',
#  'China Exchanges Resume Allowing Bitcoin Withdrawals',
#  'Take My Bitcoin...Please! A Comedian Mines the Currency for Laughs',
#  'Barclays Blockchain Leader Plans 2018 Pilot to Tackle Standards, Interoperability Issues',
#  'Behind Bitcoin’s Wild Ride: the Japan Factor',
#  'Scorching-Hot Bitcoin Drops $300 in an Hour- and Still Rises on the Day',
#  'Blockchain Firm R3 Raises $107 Million',
#  'Why Bitcoin Is Surging, Again, Up 130% This Year',
#  'Citigroup to Tap Nasdaq for Blockchain Payment Technology',
#  'How a Bitcoin Clone Helped a Company Raise $12 Million in 12 Minutes',
#  'Unreleased Disney Film Target of Online Piracy Threat',
#  'Hackers’ Apparent Take: $51,000',
#  'The Morning Download: Southwest Airlines Carefully Rolls Out New Reservation System',
#  'Bitcoin Blows Past $1,700 Mark, Up 80% This Year',
#  'Bitcoin ETF Boosts Offering Size Amid Price Rally',
#  'Bitcoin Price Hits All-Time-High Amid Speculative Surge, Liquidity Squeeze',
#  'Risk-Wary Banks Chill Bitcoin Market',
#  'Bitcoin Exchanges Hit Snags',
#  'Chain Inc. Hires Goldman’s Jessop',
#  'Bitcoin After Eight Years: More Virtual Than Real?',
#  'People Love Talking About Bitcoin More Than Using It',
#  'Corruption Currents: Reformist Ukraine Central Bank Chief Resigns',
#  'How Much Do You Know About Bitcoin?',
#  'The Anti-Bitcoin ETF',
#  'Fed’s Harker Still Sees Three Rate Increases in 2017 as Appropriate',
#  'The Future of Bitcoin Could Be Bitcoin Futures',
#  'SEC Deals Bitcoin ETF Plans Another Setback',
#  'IRS Crackdown on Bitcoin Exchange Fuels Privacy Worries',
#  'The Morning Risk Report: U.K. AML Changes Spark Skepticism, Hope',
#  'Bitcoin Price Plunges on Fears of a Currency Split',
#  'China Bitcoin Rules Would Require Exchanges to Verify Clients’ Identity',
#  'The Growing Importance of Storytelling in the Business World',
#  'Opinion: A 21st-Century Federal Reserve',
#  'Bitcoin Price Recovers as True Believers Keep the Faith',
#  'SEC Denies Winklevoss Application for a Bitcoin ETF',
#  'China Bitcoin Withdrawals on Hold, Awaiting Regulators’ Approval',
#  'The Morning Risk Report: Terrorism Financing Via Bitcoin May be Exaggerated',
#  'SEC Will Soon Decide Whether Bitcoin Could Become the Next ETF Star',
#  'Gold 2.0 (Bitcoin) Price Now Higher Than Gold 1.0 (Gold)']

# %%
words = []
for sentence in new:
    words.append(word_tokenize(sentence))

# %%
words = list(itertools.chain.from_iterable(words))

# %%
words = [i.lower() for i in words]
for i in words:
    i = re.sub(r'[^\.\?\!\w\d\s!@#$%^*():\',\.?`]','',i)
print(words)
# Out:
# ['why', 'crypto', 'stocks', 'are', 'performing', 'worse', 'than', 'cryptocurrencies', 'can', 'elon', 'musk', 'buy', 'all', 'of', 'twitter', '?', 'how', 'tesla', '’', 's', 'ceo', 'made', 'his', 'fortune', 'how', 'the', 'irs', 'is', 'cracking', 'down', 'on', 'crypto', 'tax', 'cheats', 'ukraine', ',', 'russia', 'meet', 'in', 'turkey', 'for', 'cease-fire', 'talks', 'opinion', ':', 'el', 'salvador', 'bets', 'on', 'bitcoin', 'mania', 'wall', 'street', 'has', 'been', 'betting', 'billions', 'on', 'crypto', '.', 'here', '’', 's', 'why', '.', 'el', 'salvador', 'asks', ':', 'can', 'bitcoin', 'be', 'a', 'nation', '’', 's', 'currency', '?', 'u.s.', 'stocks', 'jump', 'as', 'war', 'in', 'ukraine', 'continues', 'fueling', 'big', 'market', 'moves', 'crypto', 'in', 'wartime', ':', 'bitcoin', '’', 's', 'role', 'in', 'the', 'russia-ukraine', 'crisis', 'what', 'comes', 'next', 'in', 'el', 'salvador', '’', 's', 'bitcoin', 'experiment', '?', 'why', 'some', 'see', 'web', '3.0', 'as', 'the', 'future', 'of', 'the', 'internet', 'volatile', 'trading', 'day', 'leaves', 'u.s.', 'stocks', 'mostly', 'lower', 'turkish', 'investors', 'pivot', 'to', 'cryptocurrencies', 'as', 'inflation', 'soars', ',', 'lira', 'slides', 'opinion', ':', 'cryptocurrencies', ',', 'criminality', 'and', 'the', 'state', 'federal', 'reserve', 'signals', 'rate', 'hike', 'in', 'march', ';', 'u.s.', 'stocks', 'turn', 'lower', 'wall', 'street', "'s", 'roller-coaster', 'ride', ':', 'what', 'comes', 'next', '?', 'opinion', ':', 'cryptocurrency', 'doesn', '’', 't', 'amount', 'to', 'much', 'bitcoin', 'price', 'falls', 'in', 'tandem', 'with', 'tech', 'selloff', 'opinion', ':', 'congress', 'treats', 'bitcoin', 'like', 'stacks', 'of', 'cash', 'interest-rate', 'worries', 'spark', 'choppy', 'market', 'trading', 'session', 'stocks', 'fall', 'in', 'late', 'trading', 'why', 'crypto', 'lending', '’', 's', 'risks', 'may', 'spark', 'a', 'serious', 'regulator', 'crackdown', 'opinion', ':', 'america', '’', 's', 'future', 'depends', 'on', 'the', 'blockchain', 'how', 'to', 'give', 'crypto', ',', 'nfts', 'and', 'digital', 'money', 'this', 'holiday', 'season', 'giving', 'bitcoin', 'as', 'a', 'holiday', 'gift', '?', 'here', "'s", 'what', 'to', 'know', '.', 'nasdaq', 'leads', 'u.s.', 'stock', 'markets', 'lower', 'opinion', ':', 'no', 'deposit', 'insurance', 'for', 'crypto', 'opinion', ':', 'the', 'fed', 'battles', 'wyoming', 'on', 'cryptocurrency', 'bitcoin', "'s", 'mysterious', 'creator', 'could', 'be', 'uncovered', 'by', 'florida', 'jury', 'opinion', ':', 'crypto', 'is', 'shedding', 'its', 'tether', 'are', 'corporate', 'boards', 'heeding', 'pressure', 'to', 'diversify', '?', 'bitcoin', 'etfs', ':', 'what', 'to', 'know', 'if', 'you', 'plan', 'to', 'invest', 'u.s.', 'stocks', 'finish', 'mixed', 'after', 'weak', 'china', 'growth', 'data', 'opinion', ':', 'coinbase', 'ceo', ':', 'we', 'need', 'a', 'new', 'approach', 'to', 'regulating', 'crypto', 'opinion', ':', 'how', 'to', 'get', 'cryptocurrency', 'regulation', 'right', 'cardano', '’', 's', 'ada', 'wants', 'to', 'solve', 'some', 'of', 'crypto', '’', 's', 'biggest', 'challenges', 'energy', 'stocks', 'rally', 'as', 'investors', 'bet', 'on', 'economic', 'reopening', 'dow', ',', 's', '&', 'p', 'edge', 'higher', 'after', 'evergrande', 'payment', 'deadline', 'passes', 'how', 'to', 'invest', 'without', 'emotions', 'clouding', 'your', 'judgement', 'antony', 'blinken', 'to', 'face', 'lawmakers', 'over', 'afghanistan', 'withdrawal', 'opinion', ':', 'el', 'salvador', 'runs', 'a', 'bitcoin', 'scam', 'what', 'el', 'salvador', "'s", 'bitcoin', 'experiment', 'looks', 'like', 'opinion', ':', 'dollars', 'for', 'duds', 'in', 'latin', 'america', 'the', 'benefits', 'of', 'diversifying', 'your', 'portfolio', 'u.s.', 'stocks', 'jump', 'after', 'fda', 'approves', 'covid-19', 'vaccine', 'china', '’', 's', 'tough', 'stance', 'on', 'crypto', 'mining', 'is', 'a', 'boon', 'for', 'miners', 'elsewhere', 'dow', ',', 's', '&', 'p', 'hit', 'fresh', 'records', 'crypto', 'scams', 'are', 'on', 'the ...

# %%
import numpy as np
import itertools

# %%
taken_pos = nltk.pos_tag(words)
taken_pos
# Out:
# [('why', 'WRB'),
#  ('crypto', 'NN'),
#  ('stocks', 'NNS'),
#  ('are', 'VBP'),
#  ('performing', 'VBG'),
#  ('worse', 'JJR'),
#  ('than', 'IN'),
#  ('cryptocurrencies', 'NNS'),
#  ('can', 'MD'),
#  ('elon', 'VB'),
#  ('musk', 'JJ'),
#  ('buy', 'VB'),
#  ('all', 'DT'),
#  ('of', 'IN'),
#  ('twitter', 'NN'),
#  ('?', '.'),
#  ('how', 'WRB'),
#  ('tesla', 'JJ'),
#  ('’', 'JJ'),
#  ('s', 'NN'),
#  ('ceo', 'NN'),
#  ('made', 'VBD'),
#  ('his', 'PRP$'),
#  ('fortune', 'JJ'),
#  ('how', 'WRB'),
#  ('the', 'DT'),
#  ('irs', 'NN'),
#  ('is', 'VBZ'),
#  ('cracking', 'VBG'),
#  ('down', 'RP'),
#  ('on', 'IN'),
#  ('crypto', 'JJ'),
#  ('tax', 'NN'),
#  ('cheats', 'NNS'),
#  ('ukraine', 'VBP'),
#  (',', ','),
#  ('russia', 'JJ'),
#  ('meet', 'NN'),
#  ('in', 'IN'),
#  ('turkey', 'NN'),
#  ('for', 'IN'),
#  ('cease-fire', 'JJ'),
#  ('talks', 'NNS'),
#  ('opinion', 'NN'),
#  (':', ':'),
#  ('el', 'JJ'),
#  ('salvador', 'NN'),
#  ('bets', 'NNS'),
#  ('on', 'IN'),
#  ('bitcoin', 'NN'),
#  ('mania', 'NN'),
#  ('wall', 'NN'),
#  ('street', 'NN'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('betting', 'VBG'),
#  ('billions', 'NNS'),
#  ('on', 'IN'),
#  ('crypto', 'NN'),
#  ('.', '.'),
#  ('here', 'RB'),
#  ('’', 'JJ'),
#  ('s', 'JJ'),
#  ('why', 'WRB'),
#  ('.', '.'),
#  ('el', 'NN'),
#  ('salvador', 'NN'),
#  ('asks', 'NNS'),
#  (':', ':'),
#  ('can', 'MD'),
#  ('bitcoin', 'VB'),
#  ('be', 'VB'),
#  ('a', 'DT'),
#  ('nation', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'NN'),
#  ('currency', 'NN'),
#  ('?', '.'),
#  ('u.s.', 'JJ'),
#  ('stocks', 'NNS'),
#  ('jump', 'VBP'),
#  ('as', 'IN'),
#  ('war', 'NN'),
#  ('in', 'IN'),
#  ('ukraine', 'JJ'),
#  ('continues', 'VBZ'),
#  ('fueling', 'VBG'),
#  ('big', 'JJ'),
#  ('market', 'NN'),
#  ('moves', 'NNS'),
#  ('crypto', 'VBP'),
#  ('in', 'IN'),
#  ('wartime', 'NN'),
#  (':', ':'),
#  ('bitcoin', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'JJ'),
#  ('role', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('russia-ukraine', 'JJ'),
#  ('crisis', 'NN'),
#  ('what', 'WP'),
#  ('comes', 'VBZ'),
#  ('next', 'JJ'),
#  ('in', 'IN'),
#  ('el', 'JJ'),
#  ('salvador', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'NN'),
#  ('bitcoin', 'NN'),
#  ('experiment', 'NN'),
#  ('?', '.'),
#  ('why', 'WRB'),
#  ('some', 'DT'),
#  ('see', 'VBP'),
#  ('web', 'JJ'),
#  ('3.0', 'CD'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('future', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('internet', 'NN'),
#  ('volatile', 'JJ'),
#  ('trading', 'NN'),
#  ('day', 'NN'),
#  ('leaves', 'VBZ'),
#  ('u.s.', 'JJ'),
#  ('stocks', 'NNS'),
#  ('mostly', 'RB'),
#  ('lower', 'JJR'),
#  ('turkish', 'JJ'),
#  ('investors', 'NNS'),
#  ('pivot', 'VBP'),
#  ('to', 'TO'),
#  ('cryptocurrencies', 'NNS'),
#  ('as', 'IN'),
#  ('inflation', 'NN'),
#  ('soars', 'NNS'),
#  (',', ','),
#  ('lira', 'JJ'),
#  ('slides', 'NNS'),
#  ('opinion', 'NN'),
#  (':', ':'),
#  ('cryptocurrencies', 'NNS'),
#  (',', ','),
#  ('criminality', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('state', 'NN'),
#  ('federal', 'JJ'),
#  ('reserve', 'NN'),
#  ('signals', 'NNS'),
#  ('rate', 'NN'),
#  ('hike', 'NN'),
#  ('in', 'IN'),
#  ('march', 'NN'),
#  (';', ':'),
#  ('u.s.', 'JJ'),
#  ('stocks', 'NNS'),
#  ('turn', 'VBP'),
#  ('lower', 'JJR'),
#  ('wall', 'DT'),
#  ('street', 'NN'),
#  ("'s", 'POS'),
#  ('roller-coaster', 'JJ'),
#  ('ride', 'NN'),
#  (':', ':'),
#  ('what', 'WP'),
#  ('comes', 'VBZ'),
#  ('next', 'JJ'),
#  ('?', '.'),
#  ('opinion', 'NN'),
#  (':', ':'),
#  ('cryptocurrency', 'NN'),
#  ('doesn', 'NN'),
#  ('’', 'NNP'),
#  ('t', 'NN'),
#  ('amount', 'NN'),
#  ('to', 'TO'),
#  ('much', 'JJ'),
#  ('bitcoin', 'NN'),
#  ('price', 'NN'),
#  ('falls', 'NNS'),
#  ('in', 'IN'),
#  ('tandem', 'NN'),
#  ('with', 'IN'),
#  ('tech', 'JJ'),
#  ('selloff', 'JJ'),
#  ('opinion', 'NN'),
#  (':', ':'),
#  ('congress', 'NN'),
#  ('treats', 'VBZ'),
#  ('bitcoin', 'VBP'),
#  ('like', 'IN'),
#  ('stacks', 'NNS'),
#  ('of', 'IN'),
#  ('cash', 'NN'),
#  ('interest-rate', 'JJ'),
#  ('worries', 'NNS'),
#  ('spark', 'VBP'),
#  ('choppy', 'JJ'),
#  ('market', 'NN'),
#  ('trading', 'NN'),
#  ('session', 'NN'),
#  ('stocks', 'NNS'),
#  ('fall', 'VBP'),
#  ('in', 'IN'),
#  ('late', 'JJ'),
#  ('trading', 'NN'),
#  ('why', 'WRB'),
#  ('crypto', 'NN'),
#  ('lending', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'NN'),
#  ('risks', 'NNS'),
#  ('may', 'MD'),
#  ('spark', 'VB'),
#  ('a', 'DT'),
#  ('serious', 'JJ'),
#  ('regulator', 'NN'),
#  ('crackdown', 'JJ'),
#  ('opinion', 'NN'),
#  (':', ':'),
#  ('america', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'VBZ'),
#  ('future', 'JJ'),
#  ('depends', 'VBZ'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('blockchain', 'NN'),
#  ('how', 'WRB'),
#  ('to', 'TO'),
#  ('give', 'VB'),
#  ('crypto', 'NN'),
#  (',', ','),
#  ('nfts', 'NNS'),
#  ('and', 'CC'),
#  ('digital', 'JJ'),
#  ('money', 'NN'),
#  ('this', 'DT'),
#  ('holiday', 'NN'),
#  ('season', 'NN'),
#  ('giving', 'VBG'),
#  ('bitcoin', 'NN'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('holiday', 'NN'),
#  ('gift', 'NN'),
#  ('?', '.'),
#  ('here', 'RB'),
#  ("'s", 'VBZ'),
#  ('what', 'WP'),
#  ('to', 'TO'),
#  ('know', 'VB'),
#  ('.', '.'),
#  ('nasdaq', 'JJ'),
#  ('leads', 'VBZ'),
#  ('u.s.', 'JJ'),
#  ('stock', 'NN'),
#  ('markets', 'NNS'),
#  ('lower', 'JJR'),
#  ('opinion', 'NN'),
#  (':', ':'),
#  ('no', 'DT'),
#  ('deposit', 'NN'),
#  ('insurance', 'NN'),
#  ('for', 'IN'),
#  ('crypto', 'JJ'),
#  ('opinion', 'NN'),
#  (':', ':'),
#  ('the', 'DT'),
#  ('fed', 'NN'),
#  ('battles', 'VBZ'),
#  ('wyoming', 'VBG'),
#  ('on', 'IN'),
#  ('cryptocurrency', 'NN'),
#  ('bitcoin', 'NN'),
#  ("'s", 'POS'),
#  ('mysterious', 'JJ'),
#  ('creator', 'NN'),
#  ('could', 'MD'),
#  ('be', 'VB'),
#  ('uncovered', 'VBN'),
#  ('by', 'IN'),
#  ('florida', 'JJ'),
#  ('jury', 'NN'),
#  ('opinion', 'NN'),
#  (':', ':'),
#  ('crypto', 'NN'),
#  ('is', 'VBZ'),
#  ('shedding', 'VBG'),
#  ('its', 'PRP$'),
#  ('tether', 'NN'),
#  ('are', 'VBP'),
#  ('corporate', 'JJ'),
#  ('boards', 'NNS'),
#  ('heeding', 'VBG'),
#  ('pressure', 'NN'),
#  ('to', 'TO'),
#  ('diversify', 'VB'),
#  ('?', '.'),
#  ('bitcoin', 'JJ'),
#  ('etfs', 'NN'),
#  (':', ':'),
#  ('what', 'WP'),
#  ('to', 'TO'),
#  ('know', 'VB'),
#  ('if', 'IN'),
#  ('you', 'PRP'),
#  ('plan', 'VBP'),
#  ('to', 'TO'),
#  ('invest', 'VB'),
#  ('u.s.', 'JJ'),
#  ('stocks', 'NNS'),
#  ('finish', 'VB'),
#  ('mixed', 'JJ'),
#  ('after', 'IN'),
#  ('weak', 'JJ'),
#  ('china', 'NN'),
#  ('growth', 'NN'),
#  ('data', 'NNS'),
#  ('opinion', 'NN'),
#  (':', ':'),
#  ('coinbase', 'NN'),
#  ('ceo', 'NN'),
#  (':', ':'),
#  ('we', 'PRP'),
#  ('need', 'VBP'),
#  ('a', 'DT'),
#  ('new', 'JJ'),
#  ('approach', 'NN'),
#  ('to', 'TO'),
#  ('regulating', 'VBG'),
#  ('crypto', 'JJ'),
#  ('opinion', 'NN'),
#  (':', ':'),
#  ('how', 'WRB'),
#  ('to', 'TO'),
#  ('get', 'VB'),
#  ('cryptocurrency', 'NN'),
#  ('regulation', 'NN'),
#  ('right', 'RB'),
#  ('cardano', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'VBZ'),
#  ('ada', 'NN'),
#  ('wants', 'VBZ'),
#  ('to', 'TO'),
#  ('solve', 'VB'),
#  ('some', 'DT'),
#  ('of', 'IN'),
#  ('crypto', 'JJ'),
#  ('’', 'NNP'),
#  ('s', 'NN'),
#  ('biggest', 'JJS'),
#  ('challenges', 'VBZ'),
#  ('energy', 'NN'),
#  ('stocks', 'NNS'),
#  ('rally', 'RB'),
#  ('as', 'IN'),
#  ('investors', 'NNS'),
#  ('bet', 'VBD'),
#  ('on', 'IN'),
#  ('economic', 'JJ'),
#  ('reopening', 'NN'),
#  ('dow', 'NN'),
#  (',', ','),
#  ('s', 'NN'),
#  ('&', 'CC'),
#  ('p', 'NN'),
#  ('edge', 'NN'),
#  ('higher', 'RBR'),
#  ('after', 'IN'),
#  ('evergrande', 'JJ'),
#  ('payment', 'NN'),
#  ('deadline', 'NN'),
#  ('passes', 'VBZ'),
#  ('how', 'WRB'),
#  ('to', 'TO'),
#  ('invest', 'VB'),
#  ('without', 'IN'),
#  ('emotions', 'NNS'),
#  ('clouding', 'VBG'),
#  ('your', 'PRP$'),
#  ('judgement', 'NN'),
#  ('antony', 'NN'),
#  ('blinken', 'VBN'),
#  ('to', 'TO'),
#  ('face', 'VB'),
#  ('lawmakers', 'NNS'),
#  ('over', 'IN'),
#  ('afghanistan', 'JJ'),
#  ('withdrawal', 'JJ'),
#  ('opinion', 'NN'),
#  (':', ':'),
#  ('el', 'NN'),
#  ('salvador', 'NN'),
#  ('runs', 'VBZ'),
#  ('a', 'DT'),
#  ('bitcoin', 'NN'),
#  ('scam', 'NN'),
#  ('what', 'WP'),
#  ('el', 'VBZ'),
#  ('salvador', 'NN'),
#  ("'s", 'POS'),
#  ('bitcoin', 'JJ'),
#  ('experiment', 'JJ'),
#  ('looks', 'NNS'),
#  ('like', 'IN'),
#  ('opinion', 'NN'),
#  (':', ':'),
#  ('dollars', 'NNS'),
#  ('for', 'IN'),
#  ('duds', 'NN'),
#  ('in', 'IN'),
#  ('latin', 'NN'),
#  ('america', 'VBP'),
#  ('the', 'DT'),
#  ('benefits', 'NNS'),
#  ('of', 'IN'),
#  ('diversifying', 'VBG'),
#  ('your', 'PRP$'),
#  ('portfolio', 'NN'),
#  ('u.s.', 'JJ'),
#  ('stocks', 'NNS'),
#  ('jump', 'VBP'),
#  ('after', 'IN'),
#  ('fda', 'JJ'),
#  ('approves', 'NNS'),
#  ('covid-19', 'JJ'),
#  ('vaccine', 'JJ'),
#  ('china', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'VBZ'),
#  ('tough', 'JJ'),
#  ('stance', 'NN'),
#  ('on', 'IN'),
#  ('crypto', 'NN'),
#  ('mining', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('boon', 'NN'),
#  ('for', 'IN'),
#  ('miners', 'NNS'),
#  ('elsewhere', 'RB'),
#  ('dow', 'VBP'),
#  (',', ','),
#  ('s', 'VBP'),
#  ('&', 'CC'),
#  ('p', 'VBP'),
#  ('hit', 'VBN'),
#  ('fresh', 'JJ'),
#  ('records', 'NNS'),
#  ('crypto', 'JJ'),
#  ('scams', 'NNS'),
#  ('are', 'VBP'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('rise', 'NN'),
#  ('.', '.'),
#  ('here', 'RB'),
#  ("'s", 'VBZ'),
#  ('what', 'WP'),
#  ('to', 'TO'),
#  ('watch', 'VB'),
#  ('out', 'RP'),
#  ('for', 'IN'),
#  ('.', '.'),
#  ('opinion', 'NN'),
#  (':', ':'),
#  ('bitcoin', 'NN'),
#  ('law', 'NN'),
#  ('in', 'IN'),
#  ('el', 'JJ'),
#  ('salvador', 'NN'),
#  ('denies', 'VBZ'),
#  ('its', 'PRP$'),
#  ('people', 'NNS'),
#  ('a', 'DT'),
#  ('choice', 'NN'),
#  ('opinion', 'NN'),
#  (':', ':'),
#  ('bitcoin', 'JJ'),
#  ('experiment', 'NN'),
#  ('in', 'IN'),
#  ('el', 'JJ'),
#  ('salvador', 'NN'),
#  ('does', 'VBZ'),
#  ('not', 'RB'),
#  ('threaten', 'VB'),
#  ('freedom', 'JJ'),
#  ('opinion', 'NN'),
#  (':', ':'),
#  ('roadblocks', 'NNS'),
#  ('ahead', 'RB'),
#  ('for', 'IN'),
#  ('el', 'JJ'),
#  ('salvador', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'NN'),
#  ('crypto', 'NN'),
#  ('paradise', 'NN'),
#  ('john', 'NN'),
#  ('mcafee', 'NN'),
#  (',', ','),
#  ('software', 'NN'),
#  ('pioneer', 'NN'),
#  (',', ','),
#  ('found', 'VBN'),
#  ('dead', 'JJ'),
#  ('opinion', 'NN'),
#  (':', ':'),
#  ('el', 'JJ'),
#  ('salvador', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'VBZ'),
#  ('big', 'JJ'),
#  ('bitcoin', 'NNS'),
#  ('mistake', 'JJ'),
#  ('opinion', 'NN'),
#  (':', ':'),
#  ('untraceable', 'JJ'),
#  ('bitcoin', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('myth', 'JJ'),
#  ('opinion', 'NN'),
#  (':', ':'),
#  ('a', 'DT'),
#  ('global', 'JJ'),
#  ('first', 'JJ'),
#  (':', ':'),
#  ('bitcoin', 'NN'),
#  ('as', 'IN'),
#  ('national', 'JJ'),
#  ('currency', 'NN'),
#  ('tech', 'IN'),
#  ('stocks', 'NNS'),
#  ("'", 'POS'),
#  ('gains', 'NNS'),
#  ('push', 'VBP'),
#  ('nasdaq', 'RB'),
#  ('to', 'TO'),
#  ('record', 'VB'),
#  ('high', 'NN'),
#  ('could', 'MD'),
#  ('cryptocurrency', 'VB'),
#  ('be', 'VB'),
#  ('coming', 'VBG'),
#  ('to', 'TO'),
#  ('retirement', 'NN'),
#  ('plans', 'NNS'),
#  ('?', '.'),
#  ('trump', 'NN'),
#  ("'s", 'POS'),
#  ('tiktok', 'NN'),
#  (',', ','),
#  ('wechat', 'WP'),
#  ('orders', 'NNS'),
#  ('revoked', 'VBN'),
#  ('by', 'IN'),
#  ('biden', 'JJ'),
#  ('elon', 'NN'),
#  ('musk', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'NN'),
#  ('power', 'NN'),
#  ('over', 'IN'),
#  ('crypto', 'NN'),
#  (',', ','),
#  ('explained', 'VBD'),
#  ('how', 'WRB'),
#  ('scammers', 'NNS'),
#  ('are', 'VBP'),
#  ('taking', 'VBG'),
#  ('advantage', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('bitcoin', 'NN'),
#  ('boom', 'NN'),
#  ('investigators', 'NNS'),
#  ('seize', 'VBP'),
#  ('bitcoin', 'NN'),
#  ('paid', 'VBN'),
#  ('in', 'IN'),
#  ('colonial', 'JJ'),
#  ('pipeline', 'NN'),
#  ('ransomware', 'NN'),
#  ('attack', 'JJ'),
#  ('opinion', 'NN'),
#  (':', ':'),
#  ('crypto', 'NN'),
#  ('needs', 'VBZ'),
#  ('regulation', 'NN'),
#  (',', ','),
#  ('but', 'CC'),
#  ('it', 'PRP'),
#  ('doesn', 'VBZ'),
#  ('’', 'JJ'),
#  ('t', 'NNS'),
#  ('need', 'VBP'),
#  ('new', 'JJ'),
#  ('rules', 'NNS'),
#  ('inflation', 'NN'),
#  ('in', 'IN'),
#  ('wealthy', 'JJ'),
#  ('nations', 'NNS'),
#  ('hits', 'VBZ'),
#  ('12-year', 'JJ'),
#  ('high', 'JJ'),
#  ('investor', 'NN'),
#  ('comfort', 'NN'),
#  ('with', 'IN'),
#  ('pace', 'NN'),
#  ('of', 'IN'),
#  ('recovery', 'NN'),
#  ('pushes', 'NNS'),
#  ('markets', 'NNS'),
#  ('higher', 'JJR'),
#  ('stocks', 'NNS'),
#  ('and', 'CC'),
#  ('bitcoin', 'VB'),
#  ('move', 'NN'),
#  ('higher', 'JJR'),
#  ('to', 'TO'),
#  ('begin', 'VB'),
#  ('the', 'DT'),
#  ('week', 'NN'),
#  ('u.s.', 'JJ'),
#  ('stocks', 'NNS'),
#  ('end', 'VBP'),
#  ('bumpy', 'JJ'),
#  ('week', 'NN'),
#  ('with', 'IN'),
#  ('mixed', 'JJ'),
#  ('session', 'NN'),
#  ('existing-home', 'JJ'),
#  ('sales', 'NNS'),
#  ('fall', 'NN'),
#  ('for', 'IN'),
#  ('third', 'JJ'),
#  ('straight', 'JJ'),
#  ('month', 'NN'),
#  ('more', 'JJR'),
#  ('than', 'IN'),
#  ('20', 'CD'),
#  ('states', 'NNS'),
#  ('plan', 'VBP'),
#  ('to', 'TO'),
#  ('end', 'VB'),
#  ('extra', 'JJ'),
#  ('federal', 'JJ'),
#  ('jobless', 'JJ'),
#  ('benefits', 'NNS'),
#  ('bitcoin', 'VBP'),
#  ('volatility', 'NN'),
#  ('signals', 'NNS'),
#  ('a', 'DT'),
#  ('long', 'JJ'),
#  ('road', 'NN'),
#  ('to', 'TO'),
#  ('adoption', 'NN'),
#  ('stocks', 'NNS'),
#  (',', ','),
#  ('bitcoin', 'RB'),
#  ('drop', 'NN'),
#  ('as', 'IN'),
#  ('investors', 'NNS'),
#  ('retreat', 'VBP'),
#  ('from', 'IN'),
#  ('riskier', 'JJR'),
#  ('assets', 'NNS'),
#  ('u.s.', 'JJ'),
#  ('stocks', 'NNS'),
#  ('finish', 'VB'),
#  ('lower', 'JJR'),
#  ('to', 'TO'),
#  ('start', 'VB'),
#  ('the', 'DT'),
#  ('week', 'NN'),
#  ('crypto', 'JJ'),
#  ('venture', 'NN'),
#  ('firm', 'NN'),
#  ('framework', 'NN'),
#  ('draws', 'VBP'),
#  ('institutional', 'JJ'),
#  ('support', 'NN'),
#  ('nasdaq', 'JJ'),
#  ('drops', 'VBZ'),
#  ('1.9', 'CD'),
#  ('%', 'NN'),
#  ('as', 'IN'),
#  ('tech', 'JJ'),
#  ('stocks', 'NNS'),
#  ('fall', 'NN'),
#  ('does', 'VBZ'),
#  ('bitcoin', 'NNS'),
#  ('have', 'VB'),
#  ('a', 'DT'),
#  ('place', 'NN'),
#  ('in', 'IN'),
#  ('an', 'DT'),
#  ('investment', 'NN'),
#  ('portfolio', 'NN'),
#  ('?', '.'),
#  ('what', 'WP'),
#  ('coinbase', 'NN'),
#  ('’', 'JJ'),
#  ('s', 'JJ'),
#  ('public', 'JJ'),
#  ('debut', 'NN'),
#  ('means', 'VBZ'),
#  ('for', 'IN'),
#  ('bitcoin', 'NN'),
#  ('and', 'CC'),
#  ('crypto', 'NN'),
#  ('why', 'WRB'),
#  ('china', 'NN'),
#  ('is', 'VBZ'),
#  ('jumping', 'VBG'),
#  ('into', 'IN'),
#  ('digital', 'JJ'),
#  ('currency', 'NN'),
#  ('in', 'IN'),
#  ('bitcoin', 'NN'),
#  ("'s", 'POS'),
#  ('shadow', 'NN'),
#  (',', ','),
#  ('stablecoins', 'VBZ'),
#  ('thrive', 'JJ'),
#  ('but', 'CC'),
#  ('face', 'NN'),
#  ('challenges', 'VBZ'),
#  ('the', 'DT'),
#  ('oakland', 'NN'),
#  ('a', 'DT'),
#  ('’', 'JJ'),
#  ('s', 'NN'),
#  ('offer', 'VBP'),
#  ('a', 'DT'),
#  ('suite', 'JJ'),
#  ('bitcoin', 'NN'),
#  ('deal', 'NN'),
#  ('tax', 'NN'),
#  ('week', 'NN'),
#  (':', ':'),
#  ('investments', 'NNS'),
#  ('and', 'CC'),
#  ('your', 'PRP$'),
#  ('tax', 'NN'),
#  ('return', 'NN'),
#  ('bitcoin', 'NN'),
#  ('hits', 'VBZ'),
#  ('$', '$'),
#  ('50,000', 'CD'),
#  (':', ':'),
#  ('what', 'WP'),
#  ("'s", 'VBZ'),
#  ('fueling', 'VBG'),
#  ('the', 'DT'),
#  ('rally', 'NN'),
#  ('?', '.'),
#  ('cfos', 'JJ'),
#  ('hesitate', 'NN'),
#  ('to', 'TO'),
#  ('invest', 'VB'),
#  ('in', 'IN'),
#  (',', ','),
#  ('handle', 'VB'),
#  ('bitcoin', 'NN'),
#  ('due', 'JJ'),
#  ('to', 'TO'),
#  ('volatility', 'NN'),
#  ('opinion', 'NN'),
#  (':', ':'),
#  ('can', 'MD'),
#  ('you', 'PRP'),
#  ('get', 'VB'),
#  ('rich', 'JJ'),
#  ('with', 'IN'),
#  ('bitcoin', 'NN'),
#  ('?', '.'),
#  ('sure', 'JJ'),
#  (',', ','),
#  ('but', 'CC'),
#  ('slowly', 'RB'),
#  ('bitcoin', 'JJ'),
#  ('jumps', 'NNS'),
#  ('more', 'JJR'),
#  ('than', 'IN'),
#  ('10', 'CD'),
#  ('%', 'NN'),
#  ('on', 'IN'),
#  ('tesla', 'JJ'),
#  ('investment', 'NN'),
#  ('tesla', 'NN'),
#  ('invests', 'VBZ'),
#  ('$', '$'),
#  ('1.5', 'CD'),
#  ('billion', 'CD'),
#  ('in', 'IN'),
#  ('bitcoin', 'NN'),
#  ('dogecoin', 'NN'),
#  (':', ':'),
#  ('elon', 'NN'),
#  ('musk', 'NN'),
#  (',', ','),
#  ('snoop', 'NN'),
#  ('dogg', 'NN'),
#  ('tweets', 'NNS'),
#  ('fuel', 'VBP'),
#  ('crypto', 'JJ'),
#  ('price', 'NN'),
#  ('rally', 'NN'),
#  ('opinion', 'NN'),
#  (':', ':'),
#  ('behind', 'IN'),
#  ('the', 'DT'),
#  ('bitcoin', 'NN'),
#  ('bubble', 'JJ'),
#  ('fake', 'JJ'),
#  ('covid-19', 'JJ'),
#  ('vaccines', 'NNS'),
#  (':', ':'),
#  ('what', 'WP'),
#  ('to', 'TO'),
#  ('know', 'VB'),
#  ('about', 'IN'),
#  ('counterfeit', 'JJ'),
#  ('shots', 'NNS'),
#  ('sold', 'VBN'),
#  ('online', 'JJ'),
#  ('why', 'WRB'),
#  ('investors', 'NNS'),
#  ('are', 'VBP'),
#  ('piling', 'VBG'),
#  ('into', 'IN'),
#  ('bitcoin', 'NN'),
#  ('despite', 'IN'),
#  ('the', 'DT'),
#  ('risks', 'NNS'),
#  ('why', 'WRB'),
#  ('bitcoin', 'NN'),
#  ('prices', 'NNS'),
#  ('are', 'VBP'),
#  ('soaring', 'VBG'),
#  ('again', 'RB'),
#  ('dow', 'JJ'),
#  ('caps', 'NNS'),
#  ('best', 'JJS'),
#  ('month', 'NN'),
#  ('since', 'IN'),
#  ('1987', 'CD'),
#  ('bitcoin', 'NN'),
#  ('is', 'VBZ'),
#  ('riding', 'VBG'),
#  ('high', 'JJ'),
#  ('again', 'RB'),
#  ('as', 'IN'),
#  ('investors', 'NNS'),
#  ('embrace', 'VBP'),
#  ('risk', 'NN'),
#  ('‘', 'NN'),
#  ('billions', 'NNS'),
#  ('’', 'VBP'),
#  ('recap', 'NN'),
#  (',', ','),
#  ('season', 'NN'),
#  ('five', 'CD'),
#  ('premiere', 'NN'),
#  (':', ':'),
#  ('enlightenment', 'NN'),
#  ('and', 'CC'),
#  ('‘', 'NNP'),
#  ('deca', 'VBP'),
#  ('’', 'JJ'),
#  ('-dence', 'NN'),
#  ('opinion', 'NN'),
#  (':', ':'),
#  ('venezuela', 'NN'),
#  ('puts', 'VBZ'),
#  ('the', 'DT'),
#  ('crypt', 'NN'),
#  ('in', 'IN'),
#  ('cryptocurrency', 'NN'),
#  ('bitcoin', 'NN'),
#  ('rebounded', 'VBD'),
#  ('in', 'IN'),
#  ('2019', 'CD'),
#  (',', ','),
#  ('but', 'CC'),
#  ('challenges', 'VBZ'),
#  ('loom', 'NN'),
#  ('bitcoin', 'NN'),
#  (':', ':'),
#  ('what', 'WP'),
#  ('could', 'MD'),
#  ('trigger', 'VB'),
#  ('another', 'DT'),
#  ('rally', 'NN'),
#  ('?', '.'),
#  ('hackers', 'NNS'),
#  ('swipe', 'VBD'),
#  ('more', 'JJR'),
#  ('than', 'IN'),
#  ('$', '$'),
#  ('40', 'CD'),
#  ('million', 'CD'),
#  ('of', 'IN'),
#  ('bitcoin', 'NN'),
#  ('from', 'IN'),
#  ('cryptocurrency', 'NN'),
#  ('exchange', 'NN'),
#  ('when', 'WRB'),
#  ('warren', 'NN'),
#  ('buffett', 'NN'),
#  ('takes', 'VBZ'),
#  ('the', 'DT'),
#  ('stage', 'NN'),
#  (',', ','),
#  ('try', 'VB'),
#  ('your', 'PRP$'),
#  ('hand', 'NN'),
#  ('at', 'IN'),
#  ('berkshire', 'NN'),
#  ('bingo', 'NN'),
#  ('bitcoin', 'NN'),
#  ('venture', 'NN'),
#  ('backed', 'VBN'),
#  ('by', 'IN'),
#  ('nyse', 'NN'),
#  ('owner', 'NN'),
#  ('faces', 'VBZ'),
#  ('fresh', 'JJ'),
#  ('delay', 'NN'),
#  ('big', 'JJ'),
#  ('bitcoin', 'NN'),
#  ('exchange', 'NN'),
#  ('ends', 'VBZ'),
#  ('bid', 'NN'),
#  ('to', 'TO'),
#  ('lure', 'VB'),
#  ('high-speed', 'JJ'),
#  ('traders', 'NNS'),
#  ('private-jet', 'JJ'),
#  ('cryptocurrency', 'NN'),
#  ('gets', 'VBZ'),
#  ('pass', 'VBP'),
#  ('from', 'IN'),
#  ('sec', 'NN'),
#  ('bitcoin', 'NN'),
#  ('rises', 'VBZ'),
#  ('16', 'CD'),
#  ('%', 'NN'),
#  (',', ','),
#  ('touching', 'VBG'),
#  ('$', '$'),
#  ('5,000', 'CD'),
#  ('in', 'IN'),
#  ('asia', 'JJ'),
#  ('cryptocurrency', 'NN'),
#  (':', ':'),
#  ('coinbase', 'NN'),
#  ('offers', 'VBZ'),
#  ('interest', 'NN'),
#  ('to', 'TO'),
#  ('park', 'VB'),
#  ('cash', 'NN'),
#  ('bitcoin', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('wilderness', 'NN'),
#  ('cryptocurrency', 'NN'),
#  ('miner', 'NN'),
#  ('bitmain', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'NN'),
#  ('ipo', 'NN'),
#  ('application', 'NN'),
#  ('lapses', 'NNS'),
#  ('real', 'JJ'),
#  ('time', 'NN'),
#  ('economics', 'NNS'),
#  (':', ':'),
#  ('the', 'DT'),
#  ('fed', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'NN'),
#  ('on', 'IN'),
#  ('hold', 'NN'),
#  (',', ','),
#  ('u.s.-china', 'JJ'),
#  ('talks', 'NNS'),
#  ('are', 'VBP'),
#  ('a', 'DT'),
#  ('go', 'JJ'),
#  ('bitcoin', 'NN'),
#  ...]

# %%
NN_words = []
for words, pos in taken_pos:
    if 'NN' in pos:
        NN_words.append(words)
print(NN_words)
# Out:
# ['crypto', 'stocks', 'cryptocurrencies', 'twitter', 's', 'ceo', 'irs', 'tax', 'cheats', 'meet', 'turkey', 'talks', 'opinion', 'salvador', 'bets', 'bitcoin', 'mania', 'wall', 'street', 'billions', 'crypto', 'el', 'salvador', 'asks', 'nation', '’', 's', 'currency', 'stocks', 'war', 'market', 'moves', 'wartime', 'bitcoin', '’', 'role', 'crisis', 'salvador', '’', 's', 'bitcoin', 'experiment', 'future', 'internet', 'trading', 'day', 'stocks', 'investors', 'cryptocurrencies', 'inflation', 'soars', 'slides', 'opinion', 'cryptocurrencies', 'criminality', 'state', 'reserve', 'signals', 'rate', 'hike', 'march', 'stocks', 'street', 'ride', 'opinion', 'cryptocurrency', 'doesn', '’', 't', 'amount', 'bitcoin', 'price', 'falls', 'tandem', 'opinion', 'congress', 'stacks', 'cash', 'worries', 'market', 'trading', 'session', 'stocks', 'trading', 'crypto', 'lending', '’', 's', 'risks', 'regulator', 'opinion', 'america', '’', 'blockchain', 'crypto', 'nfts', 'money', 'holiday', 'season', 'bitcoin', 'holiday', 'gift', 'stock', 'markets', 'opinion', 'deposit', 'insurance', 'opinion', 'fed', 'cryptocurrency', 'bitcoin', 'creator', 'jury', 'opinion', 'crypto', 'tether', 'boards', 'pressure', 'etfs', 'stocks', 'china', 'growth', 'data', 'opinion', 'coinbase', 'ceo', 'approach', 'opinion', 'cryptocurrency', 'regulation', 'cardano', '’', 'ada', '’', 's', 'energy', 'stocks', 'investors', 'reopening', 'dow', 's', 'p', 'edge', 'payment', 'deadline', 'emotions', 'judgement', 'antony', 'lawmakers', 'opinion', 'el', 'salvador', 'bitcoin', 'scam', 'salvador', 'looks', 'opinion', 'dollars', 'duds', 'latin', 'benefits', 'portfolio', 'stocks', 'approves', 'china', '’', 'stance', 'crypto', 'mining', 'boon', 'miners', 'records', 'scams', 'rise', 'opinion', 'bitcoin', 'law', 'salvador', 'people', 'choice', 'opinion', 'experiment', 'salvador', 'opinion', 'roadblocks', 'salvador', '’', 's', 'crypto', 'paradise', 'john', 'mcafee', 'software', 'pioneer', 'opinion', 'salvador', '’', 'bitcoin', 'opinion', 'bitcoin', 'opinion', 'bitcoin', 'currency', 'stocks', 'gains', 'high', 'retirement', 'plans', 'trump', 'tiktok', 'orders', 'elon', 'musk', '’', 's', 'power', 'crypto', 'scammers', 'advantage', 'bitcoin', 'boom', 'investigators', 'bitcoin', 'pipeline', 'ransomware', 'opinion', 'crypto', 'regulation', 't', 'rules', 'inflation', 'nations', 'investor', 'comfort', 'pace', 'recovery', 'pushes', 'markets', 'stocks', 'move', 'week', 'stocks', 'week', 'session', 'sales', 'fall', 'month', 'states', 'benefits', 'volatility', 'signals', 'road', 'adoption', 'stocks', 'drop', 'investors', 'assets', 'stocks', 'week', 'venture', 'firm', 'framework', 'support', '%', 'stocks', 'fall', 'bitcoin', 'place', 'investment', 'portfolio', 'coinbase', 'debut', 'bitcoin', 'crypto', 'china', 'currency', 'bitcoin', 'shadow', 'face', 'oakland', 's', 'bitcoin', 'deal', 'tax', 'week', 'investments', 'tax', 'return', 'bitcoin', 'rally', 'hesitate', 'bitcoin', 'volatility', 'opinion', 'bitcoin', 'jumps', '%', 'investment', 'tesla', 'bitcoin', 'dogecoin', 'elon', 'musk', 'snoop', 'dogg', 'tweets', 'price', 'rally', 'opinion', 'bitcoin', 'vaccines', 'shots', 'investors', 'bitcoin', 'risks', 'bitcoin', 'prices', 'caps', 'month', 'bitcoin', 'investors', 'risk', '‘', 'billions', 'recap', 'season', 'premiere', 'enlightenment', '‘', '-dence', 'opinion', 'venezuela', 'crypt', 'cryptocurrency', 'bitcoin', 'loom', 'bitcoin', 'rally', 'hackers', 'bitcoin', 'cryptocurrency', 'exchange', 'warren', 'buffett', 'stage', 'hand', 'berkshire', 'bingo', 'bitcoin', 'venture', 'nyse', 'owner', 'delay', 'bitcoin', 'exchange', 'bid', 'traders', 'cryptocurrency', 'sec', 'bitcoin', '%', 'cryptocurrency', 'coinbase', 'interest', 'cash', 'bitcoin', 'wilderness', 'cryptocurrency', 'miner', 'bitmain', '’', 's', 'ipo', 'application', 'lapses', 'time', 'economics', 'fed', '’', 's', 'hold', 'talks', 'bitcoin', 'crypto', 'winter', 'discontent', 'mt', 'gox', 'bitcoin', 'bigwig', 'jail', 'time', 'customers', 'exchange', '’', 's', 'millions', ...

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
wlem = nltk.WordNetLemmatizer()
lemmatized_words = []
for word in NN_words:
    new_word = wlem.lemmatize(word)
    lemmatized_words.append(new_word)
print(lemmatized_words)
# Out:
# ['crypto', 'stock', 'cryptocurrencies', 'twitter', 's', 'ceo', 'irs', 'tax', 'cheat', 'meet', 'turkey', 'talk', 'opinion', 'salvador', 'bet', 'bitcoin', 'mania', 'wall', 'street', 'billion', 'crypto', 'el', 'salvador', 'asks', 'nation', '’', 's', 'currency', 'stock', 'war', 'market', 'move', 'wartime', 'bitcoin', '’', 'role', 'crisis', 'salvador', '’', 's', 'bitcoin', 'experiment', 'future', 'internet', 'trading', 'day', 'stock', 'investor', 'cryptocurrencies', 'inflation', 'soar', 'slide', 'opinion', 'cryptocurrencies', 'criminality', 'state', 'reserve', 'signal', 'rate', 'hike', 'march', 'stock', 'street', 'ride', 'opinion', 'cryptocurrency', 'doesn', '’', 't', 'amount', 'bitcoin', 'price', 'fall', 'tandem', 'opinion', 'congress', 'stack', 'cash', 'worry', 'market', 'trading', 'session', 'stock', 'trading', 'crypto', 'lending', '’', 's', 'risk', 'regulator', 'opinion', 'america', '’', 'blockchain', 'crypto', 'nfts', 'money', 'holiday', 'season', 'bitcoin', 'holiday', 'gift', 'stock', 'market', 'opinion', 'deposit', 'insurance', 'opinion', 'fed', 'cryptocurrency', 'bitcoin', 'creator', 'jury', 'opinion', 'crypto', 'tether', 'board', 'pressure', 'etf', 'stock', 'china', 'growth', 'data', 'opinion', 'coinbase', 'ceo', 'approach', 'opinion', 'cryptocurrency', 'regulation', 'cardano', '’', 'ada', '’', 's', 'energy', 'stock', 'investor', 'reopening', 'dow', 's', 'p', 'edge', 'payment', 'deadline', 'emotion', 'judgement', 'antony', 'lawmaker', 'opinion', 'el', 'salvador', 'bitcoin', 'scam', 'salvador', 'look', 'opinion', 'dollar', 'dud', 'latin', 'benefit', 'portfolio', 'stock', 'approves', 'china', '’', 'stance', 'crypto', 'mining', 'boon', 'miner', 'record', 'scam', 'rise', 'opinion', 'bitcoin', 'law', 'salvador', 'people', 'choice', 'opinion', 'experiment', 'salvador', 'opinion', 'roadblock', 'salvador', '’', 's', 'crypto', 'paradise', 'john', 'mcafee', 'software', 'pioneer', 'opinion', 'salvador', '’', 'bitcoin', 'opinion', 'bitcoin', 'opinion', 'bitcoin', 'currency', 'stock', 'gain', 'high', 'retirement', 'plan', 'trump', 'tiktok', 'order', 'elon', 'musk', '’', 's', 'power', 'crypto', 'scammer', 'advantage', 'bitcoin', 'boom', 'investigator', 'bitcoin', 'pipeline', 'ransomware', 'opinion', 'crypto', 'regulation', 't', 'rule', 'inflation', 'nation', 'investor', 'comfort', 'pace', 'recovery', 'push', 'market', 'stock', 'move', 'week', 'stock', 'week', 'session', 'sale', 'fall', 'month', 'state', 'benefit', 'volatility', 'signal', 'road', 'adoption', 'stock', 'drop', 'investor', 'asset', 'stock', 'week', 'venture', 'firm', 'framework', 'support', '%', 'stock', 'fall', 'bitcoin', 'place', 'investment', 'portfolio', 'coinbase', 'debut', 'bitcoin', 'crypto', 'china', 'currency', 'bitcoin', 'shadow', 'face', 'oakland', 's', 'bitcoin', 'deal', 'tax', 'week', 'investment', 'tax', 'return', 'bitcoin', 'rally', 'hesitate', 'bitcoin', 'volatility', 'opinion', 'bitcoin', 'jump', '%', 'investment', 'tesla', 'bitcoin', 'dogecoin', 'elon', 'musk', 'snoop', 'dogg', 'tweet', 'price', 'rally', 'opinion', 'bitcoin', 'vaccine', 'shot', 'investor', 'bitcoin', 'risk', 'bitcoin', 'price', 'cap', 'month', 'bitcoin', 'investor', 'risk', '‘', 'billion', 'recap', 'season', 'premiere', 'enlightenment', '‘', '-dence', 'opinion', 'venezuela', 'crypt', 'cryptocurrency', 'bitcoin', 'loom', 'bitcoin', 'rally', 'hacker', 'bitcoin', 'cryptocurrency', 'exchange', 'warren', 'buffett', 'stage', 'hand', 'berkshire', 'bingo', 'bitcoin', 'venture', 'nyse', 'owner', 'delay', 'bitcoin', 'exchange', 'bid', 'trader', 'cryptocurrency', 'sec', 'bitcoin', '%', 'cryptocurrency', 'coinbase', 'interest', 'cash', 'bitcoin', 'wilderness', 'cryptocurrency', 'miner', 'bitmain', '’', 's', 'ipo', 'application', 'lapse', 'time', 'economics', 'fed', '’', 's', 'hold', 'talk', 'bitcoin', 'crypto', 'winter', 'discontent', 'mt', 'gox', 'bitcoin', 'bigwig', 'jail', 'time', 'customer', 'exchange', '’', 's', 'million', 'crypto-mystery', 'stuck', 'group', 'cryptocurrency', 'hack', 'token', 'se ...

# %%
from nltk.corpus import stopwords

# %%
stopwords_list = stopwords.words('english')
unique_NN_words = set(lemmatized_words)
final_NN_words = lemmatized_words

# 불용어 제거
for word in unique_NN_words:
    if word in stopwords_list:
        while word in final_NN_words: final_NN_words.remove(word)

# %%
#customized_stopwords = ['bitcoin', 'opinion', 'morning', "’", "download", 'market','price','currency','etf','china', 'exchange','investor','report','salvador','‘','cryptocurrencies','%'] # 직접 만든 불용어 사전
customized_stopwords = ['opinion','cryptocurrency','morning', "’", "download", 'market','price','currency','etf','china', 'exchange','investor','report','salvador','‘','cryptocurrencies','%']
unique_NN_words1 = set(final_NN_words)
for word in unique_NN_words1:
    if word in customized_stopwords:
        while word in final_NN_words: final_NN_words.remove(word)

print(final_NN_words)
# Out:
# ['crypto', 'stock', 'twitter', 'ceo', 'irs', 'tax', 'cheat', 'meet', 'turkey', 'talk', 'bet', 'bitcoin', 'mania', 'wall', 'street', 'billion', 'crypto', 'el', 'asks', 'nation', 'stock', 'war', 'move', 'wartime', 'bitcoin', 'role', 'crisis', 'bitcoin', 'experiment', 'future', 'internet', 'trading', 'day', 'stock', 'inflation', 'soar', 'slide', 'criminality', 'state', 'reserve', 'signal', 'rate', 'hike', 'march', 'stock', 'street', 'ride', 'amount', 'bitcoin', 'fall', 'tandem', 'congress', 'stack', 'cash', 'worry', 'trading', 'session', 'stock', 'trading', 'crypto', 'lending', 'risk', 'regulator', 'america', 'blockchain', 'crypto', 'nfts', 'money', 'holiday', 'season', 'bitcoin', 'holiday', 'gift', 'stock', 'deposit', 'insurance', 'fed', 'bitcoin', 'creator', 'jury', 'crypto', 'tether', 'board', 'pressure', 'stock', 'growth', 'data', 'coinbase', 'ceo', 'approach', 'regulation', 'cardano', 'ada', 'energy', 'stock', 'reopening', 'dow', 'p', 'edge', 'payment', 'deadline', 'emotion', 'judgement', 'antony', 'lawmaker', 'el', 'bitcoin', 'scam', 'look', 'dollar', 'dud', 'latin', 'benefit', 'portfolio', 'stock', 'approves', 'stance', 'crypto', 'mining', 'boon', 'miner', 'record', 'scam', 'rise', 'bitcoin', 'law', 'people', 'choice', 'experiment', 'roadblock', 'crypto', 'paradise', 'john', 'mcafee', 'software', 'pioneer', 'bitcoin', 'bitcoin', 'bitcoin', 'stock', 'gain', 'high', 'retirement', 'plan', 'trump', 'tiktok', 'order', 'elon', 'musk', 'power', 'crypto', 'scammer', 'advantage', 'bitcoin', 'boom', 'investigator', 'bitcoin', 'pipeline', 'ransomware', 'crypto', 'regulation', 'rule', 'inflation', 'nation', 'comfort', 'pace', 'recovery', 'push', 'stock', 'move', 'week', 'stock', 'week', 'session', 'sale', 'fall', 'month', 'state', 'benefit', 'volatility', 'signal', 'road', 'adoption', 'stock', 'drop', 'asset', 'stock', 'week', 'venture', 'firm', 'framework', 'support', 'stock', 'fall', 'bitcoin', 'place', 'investment', 'portfolio', 'coinbase', 'debut', 'bitcoin', 'crypto', 'bitcoin', 'shadow', 'face', 'oakland', 'bitcoin', 'deal', 'tax', 'week', 'investment', 'tax', 'return', 'bitcoin', 'rally', 'hesitate', 'bitcoin', 'volatility', 'bitcoin', 'jump', 'investment', 'tesla', 'bitcoin', 'dogecoin', 'elon', 'musk', 'snoop', 'dogg', 'tweet', 'rally', 'bitcoin', 'vaccine', 'shot', 'bitcoin', 'risk', 'bitcoin', 'cap', 'month', 'bitcoin', 'risk', 'billion', 'recap', 'season', 'premiere', 'enlightenment', '-dence', 'venezuela', 'crypt', 'bitcoin', 'loom', 'bitcoin', 'rally', 'hacker', 'bitcoin', 'warren', 'buffett', 'stage', 'hand', 'berkshire', 'bingo', 'bitcoin', 'venture', 'nyse', 'owner', 'delay', 'bitcoin', 'bid', 'trader', 'sec', 'bitcoin', 'coinbase', 'interest', 'cash', 'bitcoin', 'wilderness', 'miner', 'bitmain', 'ipo', 'application', 'lapse', 'time', 'economics', 'fed', 'hold', 'talk', 'bitcoin', 'crypto', 'winter', 'discontent', 'mt', 'gox', 'bitcoin', 'bigwig', 'jail', 'time', 'customer', 'million', 'crypto-mystery', 'stuck', 'group', 'hack', 'token', 'security', 'startup', 'judge', 'cryptomom', 'startup', 'scammer', 'fraud', 'watchdog', 'cryptomom', 'world', 'cash', 'rebound', 'decline', 'rebel', 'bitcoin', 'mainstream', 'flood', 'offering', 'bitcoin', 'gamble', 'sell', 'contract', 'bitcoin', 'blockchain', 'hype', 'blythe', 'master', 'wall', 'street', 'star', 'blockchain', 'startup', 'bitcoin', 'future', 'blockchains', 'enterprise', 'bitcoin', 'bitcoin', 'thing', 'rage—until', 'iranian', 'atlanta', 'cyberattack', 'elevator', 'coinbase', 'ceo', 'brian', 'pay', 'tax', 'bitcoin', 'ohio', 'time', 'economics', 'brexit', 'bust', 'climate', 'change', 'bitcoin', 'week', 'bitcoin', 'volatility', 'turmoil', 'volatility', 'startup', 'wealth', 'manager', 'bitcoin', 'man', 'bitcoin', 'bitcoin', 'fidelity', 'bitcoin', 'hedge', 'fund', 'journalism', 'draw', 'skepticism', 'scam', 'scam', 'rise', 'wsjcoin', 'wsjcoin', 'bitcoin', 'birthday', 'blockchains', 'year', 'crypto', 'street', 'bitcoin', 'mining', 'giant', 'file', 'bitcoin', 'regulator', 're ...

# %%
from collections import Counter
c = Counter(final_NN_words) # input type should be a list of words (or tokens)
print(c)
k = 5
print(c.most_common(k)) # 빈도수 기준 상위 k개 단어 출력
# Out:
# Counter({'bitcoin': 156, 'crypto': 21, 'stock': 21, 'future': 21, 'risk': 17, 'blockchain': 16, 'tax': 8, 'week': 8, 'time': 8, 'bank': 8, 'street': 7, 'trading': 7, 'cash': 7, 'regulator': 7, 'rally': 7, 'fund': 7, 'year': 7, 'plan': 6, 'volatility': 6, 'trader': 6, 'sec': 6, 'startup': 6, 'gold': 6, 'company': 6, 'ceo': 5, 'fall': 5, 'money': 5, 'coinbase': 5, 'regulation': 5, 'rise': 5, 'month': 5, 'hacker': 5, 'hack': 5, 'offering': 5, 'corruption': 5, 'buyer': 5, 'coin': 5, 'day': 4, 'fed': 4, 'energy': 4, 'scam': 4, 'people': 4, 'power': 4, 'boom': 4, 'push': 4, 'investment': 4, 'economics': 4, 'world': 4, 'thing': 4, 'current': 4, 'crackdown': 4, 'plunge': 4, 'talk': 3, 'mania': 3, 'wall': 3, 'move': 3, 'role': 3, 'experiment': 3, 'rate': 3, 'ride': 3, 'holiday': 3, 'board': 3, 'payment': 3, 'mining': 3, 'record': 3, 'law': 3, 'rule': 3, 'venture': 3, 'firm': 3, 'deal': 3, 'mt': 3, 'million': 3, 'contract': 3, 'change': 3, 'manager': 3, 'man': 3, 'hedge': 3, 'giant': 3, 'trade': 3, 'others': 3, 'york': 3, 'surge': 3, 'japan': 3, 'pivot': 3, 'business': 3, 'hour': 3, 'cio': 3, 'irs': 2, 'turkey': 2, 'bet': 2, 'billion': 2, 'el': 2, 'nation': 2, 'internet': 2, 'inflation': 2, 'slide': 2, 'state': 2, 'reserve': 2, 'signal': 2, 'worry': 2, 'session': 2, 'season': 2, 'insurance': 2, 'tether': 2, 'dollar': 2, 'benefit': 2, 'portfolio': 2, 'stance': 2, 'miner': 2, 'paradise': 2, 'software': 2, 'pioneer': 2, 'gain': 2, 'high': 2, 'order': 2, 'elon': 2, 'musk': 2, 'scammer': 2, 'drop': 2, 'debut': 2, 'return': 2, 'cap': 2, 'warren': 2, 'buffett': 2, 'owner': 2, 'interest': 2, 'application': 2, 'hold': 2, 'gox': 2, 'customer': 2, 'token': 2, 'cryptomom': 2, 'fraud': 2, 'hype': 2, 'star': 2, 'blockchains': 2, 'enterprise': 2, 'climate': 2, 'skepticism': 2, 'wsjcoin': 2, 'file': 2, 'manipulation': 2, 'leader': 2, 'trial': 2, 'fever': 2, 'court': 2, 'chief': 2, 'official': 2, 'launch': 2, 'battle': 2, 'developer': 2, 'maker': 2, 'beware': 2, 'crash': 2, 'loss': 2, 'app': 2, 'message': 2, 'fizzle': 2, 'nasdaq': 2, 'banker': 2, 'warns': 2, 'coincheck': 2, 'play': 2, 'computer': 2, 'france': 2, 'split': 2, 'korea': 2, 'race': 2, 'rout': 2, 'name': 2, 'brief': 2, 'profit': 2, 'sign': 2, 'closing': 2, 'clone': 2, 'bull': 2, 'recovers': 2, 'swing': 2, 'news': 2, 'case': 2, 'head': 2, 'commissioner': 2, 'cybersecurity': 2, 'test': 2, 'faith': 2, 'drive': 2, 'technology': 2, 'individual': 2, 'threat': 2, 'withdrawal': 2, 'twitter': 1, 'cheat': 1, 'meet': 1, 'asks': 1, 'war': 1, 'wartime': 1, 'crisis': 1, 'soar': 1, 'criminality': 1, 'hike': 1, 'march': 1, 'amount': 1, 'tandem': 1, 'congress': 1, 'stack': 1, 'lending': 1, 'america': 1, 'nfts': 1, 'gift': 1, 'deposit': 1, 'creator': 1, 'jury': 1, 'pressure': 1, 'growth': 1, 'data': 1, 'approach': 1, 'cardano': 1, 'ada': 1, 'reopening': 1, 'dow': 1, 'p': 1, 'edge': 1, 'deadline': 1, 'emotion': 1, 'judgement': 1, 'antony': 1, 'lawmaker': 1, 'look': 1, 'dud': 1, 'latin': 1, 'approves': 1, 'boon': 1, 'choice': 1, 'roadblock': 1, 'john': 1, 'mcafee': 1, 'retirement': 1, 'trump': 1, 'tiktok': 1, 'advantage': 1, 'investigator': 1, 'pipeline': 1, 'ransomware': 1, 'comfort': 1, 'pace': 1, 'recovery': 1, 'sale': 1, 'road': 1, 'adoption': 1, 'asset': 1, 'framework': 1, 'support': 1, 'place': 1, 'shadow': 1, 'face': 1, 'oakland': 1, 'hesitate': 1, 'jump': 1, 'tesla': 1, 'dogecoin': 1, 'snoop': 1, 'dogg': 1, 'tweet': 1, 'vaccine': 1, 'shot': 1, 'recap': 1, 'premiere': 1, 'enlightenment': 1, '-dence': 1, 'venezuela': 1, 'crypt': 1, 'loom': 1, 'stage': 1, 'hand': 1, 'berkshire': 1, 'bingo': 1, 'nyse': 1, 'delay': 1, 'bid': 1, 'wilderness': 1, 'bitmain': 1, 'ipo': 1, 'lapse': 1, 'winter': 1, 'discontent': 1, 'bigwig': 1, 'jail': 1, 'crypto-mystery': 1, 'stuck': 1, 'group': 1, 'security': 1, 'judge': 1, 'watchdog': 1, 'rebound': 1, 'decline': 1, 'rebel': 1, 'mainstream': 1, 'flood': 1, 'gamble': 1, 'sell': 1, 'blythe': 1, 'master': 1, 'rage—until': 1, 'iranian': 1, 'atlanta': 1, 'cyberattack': 1, 'elevator':  ...
# [('bitcoin', 156), ('crypto', 21), ('stock', 21), ('future', 21), ('risk', 17)]

# %%
import pandas as pd

# %%
df_c = pd.DataFrame(list(c.items()),columns=['keywords','freq'])
df_c = df_c.sort_values('freq', ascending=False).head(20).reset_index(drop=True)
df_c
# Out:
#       keywords  freq
# 0      bitcoin   156
# 1       crypto    21
# 2        stock    21
# 3       future    21
# 4         risk    17
# 5   blockchain    16
# 6         bank     8
# 7          tax     8
# 8         week     8
# 9         time     8
# 10        fund     7
# 11       rally     7
# 12        cash     7
# 13      street     7
# 14        year     7
# 15     trading     7
# 16   regulator     7
# 17        gold     6
# 18         sec     6
# 19     company     6

# %%
import wordcloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from os import path

noun_text = ''
for word in final_NN_words:
    noun_text = noun_text +' '+word

wordcloud = WordCloud(max_font_size=60, relative_scaling=.5).generate(noun_text) # generate() 는 하나의 string value를 입력 받음
plt.figure()
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud = WordCloud(max_font_size=50, max_words=20, background_color='white', relative_scaling=.5).generate(noun_text)
plt.figure()
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
